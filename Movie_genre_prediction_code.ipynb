# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import LabelEncoder
sep= ':::'

# %%
train_data= pd.read_csv(r'C:\Users\lenovo\OneDrive\Desktop\Movie genre prediction\train_data.txt',sep=':::', names=['Title', 'Genre', 'Description'], engine='python')
test_data= pd.read_csv(r'C:\Users\lenovo\OneDrive\Desktop\Movie genre prediction\test_data.txt',sep=':::', names=['Title', 'Genre', 'Description'], engine='python')
test_data_solution= pd.read_csv(r'C:\Users\lenovo\OneDrive\Desktop\Movie genre prediction\test_data_solution.txt',sep=':::', names=['Title', 'Genre', 'Description'], engine='python')

# %%
print("Train Data Columns and Samples")
print(train_data.columns)
print(train_data.head())

print("\nTest Data Columns and Sample:")
print(test_data.columns)
print(train_data.head())

print("\nTest data solution Columns and Sample:")
print(test_data_solution.columns)
print(test_data_solution.head())
# Out:
# Train Data Columns and Samples
# Index(['Title', 'Genre', 'Description'], dtype='object')
#                                 Title       Genre  \
# 1       Oscar et la dame rose (2009)       drama
# 2                       Cupid (1997)    thriller
# 3   Young, Wild and Wonderful (1980)       adult
# 4              The Secret Sin (1915)       drama
# 5             The Unrecovered (2007)       drama
#
#                                          Description
# 1   Listening in to a conversation between his do...
# 2   A brother and sister with a past incestuous r...
# 3   As the bus empties the students for their fie...
# 4   To help their unemployed father make ends mee...
# 5   The film's title refers not only to the un-re...
#
# Test Data Columns and Sample:
# Index(['Title', 'Genre', 'Description'], dtype='object')
#                                 Title       Genre  \
# 1       Oscar et la dame rose (2009)       drama
# 2                       Cupid (1997)    thriller
# ...

# %%
plot_column= 'Description'
genre_column='Genre'

train_data[plot_column].fillna('',inplace=True)
test_data[plot_column].fillna('',inplace=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6704\3800503596.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   train_data[plot_column].fillna('',inplace=True)
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_6704\3800503596.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
label_encoder= LabelEncoder()
train_data['genre_encoded']= label_encoder.fit_transform(train_data[genre_column])

# %%
#Text vectorization using TF-IDF

tfidf_vectorizer= TfidfVectorizer(max_features=5000, stop_words='english')
X_train_tfidf= tfidf_vectorizer.fit_transform(train_data[plot_column])
X_test_tfidf= tfidf_vectorizer.transform(test_data[plot_column])

# %%
#features and target variable
X= X_train_tfidf
Y= train_data['genre_encoded']

# %%
# Split the data into training and validation data
X_train, X_val, Y_train, Y_val= train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
#Importing the Logistic Regression Model
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# %%
#Initialize and train the model
model= LogisticRegression(max_iter=1000)
model.fit(X_train, Y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %% [markdown]
# LOGISTIC REGRESSION

# %% [markdown]
# ACCURACY:

# %%
#predict on the validation set

Y_val_predict= model.predict(X_val)

#Evaluate the model
print("Accuracy:", accuracy_score(Y_val,Y_val_predict))
# Out:
# Accuracy: 0.5789910541363091

# %%
print(classification_report(Y_val, Y_val_predict, target_names= label_encoder.classes_))
# Out:
#                precision    recall  f1-score   support
#
#       action        0.52      0.26      0.35       263
#        adult        0.75      0.21      0.33       112
#    adventure        0.43      0.14      0.21       139
#    animation        0.56      0.09      0.15       104
#    biography        0.00      0.00      0.00        61
#       comedy        0.51      0.58      0.55      1443
#        crime        0.29      0.02      0.04       107
#  documentary        0.66      0.84      0.74      2659
#        drama        0.54      0.78      0.64      2697
#       family        0.41      0.07      0.12       150
#      fantasy        0.00      0.00      0.00        74
#    game-show        0.94      0.42      0.59        40
#      history        0.00      0.00      0.00        45
#       horror        0.64      0.56      0.60       431
#        music        0.62      0.47      0.54       144
#      musical        1.00      0.02      0.04        50
# ...

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
#initialize and train the model

nb= MultinomialNB()
nb.fit(X_train, Y_train)
# Out:
# MultinomialNB()

# %% [markdown]
# Naive Bayes

# %% [markdown]
# Accuracy:

# %%
#Predict on the validation set
Y_val_predict= nb.predict(X_val)

#Evaluate the model
print("Accuracy:",accuracy_score(Y_val, Y_val_predict))
# Out:
# Accuracy: 0.52310246241815

# %%
print(classification_report(Y_val,Y_val_predict,target_names=label_encoder.classes_))
# Out:
#                precision    recall  f1-score   support
#
#       action        0.57      0.08      0.14       263
#        adult        0.88      0.06      0.12       112
#    adventure        0.29      0.03      0.05       139
#    animation        0.00      0.00      0.00       104
#    biography        0.00      0.00      0.00        61
#       comedy        0.51      0.44      0.47      1443
#        crime        0.00      0.00      0.00       107
#  documentary        0.58      0.88      0.70      2659
#        drama        0.46      0.83      0.59      2697
#       family        1.00      0.01      0.01       150
#      fantasy        0.00      0.00      0.00        74
#    game-show        1.00      0.15      0.26        40
#      history        0.00      0.00      0.00        45
#       horror        0.73      0.38      0.50       431
#        music        0.79      0.10      0.18       144
#      musical        0.00      0.00      0.00        50
# ...

# %%
from sklearn.svm import LinearSVC

# %%
#Initialize and train the model
svc= LinearSVC(max_iter=1000)
svc.fit(X_train, Y_train)
# Out:
# LinearSVC()

# %%
#predict on validation set
Y_val_predict= svc.predict(X_val)

# %% [markdown]
# SUPPORT VECTOR MACHINE

# %% [markdown]
# ACCURACY:

# %%
print("Accuracy:", accuracy_score(Y_val,Y_val_predict))
# Out:
# Accuracy: 0.5686618094623259

# %%
print(classification_report(Y_val,Y_val_predict,target_names= label_encoder.classes_))
# Out:
#                precision    recall  f1-score   support
#
#       action        0.41      0.32      0.36       263
#        adult        0.59      0.38      0.46       112
#    adventure        0.31      0.22      0.26       139
#    animation        0.40      0.18      0.25       104
#    biography        0.00      0.00      0.00        61
#       comedy        0.51      0.56      0.53      1443
#        crime        0.21      0.06      0.09       107
#  documentary        0.69      0.81      0.75      2659
#        drama        0.56      0.70      0.62      2697
#       family        0.24      0.12      0.16       150
#      fantasy        0.09      0.01      0.02        74
#    game-show        0.71      0.68      0.69        40
#      history        0.00      0.00      0.00        45
#       horror        0.60      0.63      0.61       431
#        music        0.54      0.53      0.54       144
#      musical        0.00      0.00      0.00        50
# ...
